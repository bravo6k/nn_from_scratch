# %% [markdown]
# Author: Zhengxiang (Jack) Wang <br>
# Date: 2021-06-22 <br>
# GitHub: https://github.com/jaaack-wang <br>
# About: The current scripts scrapes Chinese Names from http://www.resgain.net/xmdq.html <br>

# %%
import requests
import re
from bs4 import BeautifulSoup as bs
from threading import Thread
from time import time

# %%
def getHTML(url, headers=None):
    '''
    Paras:
        url: str --> a url link
        headers: settings for headers in dict format. By default = None.
    Returns: the html content of a url; or False if the url is invalid. 
    '''
    r = requests.get(url, headers=headers)
    if r.status_code == 200:
        return r.content
    else:
        print(f'【{url}】 is not working!')
        return False

    
def getMetaData(url, headers=None):
    '''
    Returns the following three lists:
        1. Chinese last names
        2. Counts of different full names associated with the last names
        3. The links to full names associated with the last names
    '''
    html = getHTML(url, headers=headers)
    if html:
        soup = bs(html, 'lxml')
        names = soup.select('body > div.main_ > div > div > div > a')
        lastNames = []
        counts = []
        links = []
        for name in names:
            ln = re.search(r'.+(?=姓名字大全)', name.string)
            lastNames.append(ln.group())
            cts = re.search(r'\d+', name['title']).group()
            counts.append(int(cts))
            links.append('http:' + name['href'])
        return lastNames, counts, links        


def getNameLinksByGender(lname_link):
    '''
    Generates all the possible links to names related to a specific last name by gender.
    It turns out that for each name category, there are at most 18 webpages available even when 
    the number of full names related to a last name is much larger than that. One way to get as 
    many names as possible is thus to get full names by gender. 
    ----------------
    Paras:
        lname_link: a link related to a last name extracted from getMetaData
    Return: two list of links of two genders
    '''
    boy = lname_link + '&gender=1'
    girl = lname_link + '&gender=1'
    boy_links = []
    girl_links = []
    for i in range(1, 19):
        boy_links.append(boy.format(i))
        girl_links.append(girl.format(i))

    return boy_links, girl_links
    


def getFullNames(urls, headers=None):
    '''
    Paras: 
        urls: list --> a list of urls
    Returns:
        list --> a list of full names in given webpages.   
    '''
    fullnames = []
    for url in urls:
        html = getHTML(url, headers=headers)
        if html:
            soup = bs(html, 'lxml')
            names = soup.select('body > div.main_ > div > div > div > div')
            fullnames.extend([name.div.string for name in names[:-1]])
            
    return fullnames
    

def getFirstNames(fullName, lastName):
    '''
    Works for names where last name comes first and there is no space
    between the first name and the last name. 
    ----------------
    Paras:
        fullName: str or list
        lastName: str
    ----------------
    Return:
        firstNames: str or list
    '''
    firstName = lambda fullName, lastName: fullName[len(lastName):]
    if isinstance(fullName, list):
        return list(map(firstName, fullName, [lastName] * len(fullName)))
    
    elif isinstance(fullName, str):
        return firstName(fullName, lastName)
    
    else:
        raise ValueError('fullName should be either list or str')


def nameInfoWriter(lname, lname_link, writer, template):
    '''
    Write the following information into a file：
        1. Last Name
        2. First Name
        3. Full Name
        4. Gender
    Paras:
        lname: str --> last name
        lname_link: str --> link related to the last name
        writer: f = open(filename, 'w')
        template: formatted string for writing a file
    '''
    boy_links, girl_links = getNameLinksByGender(lname_link)
    # get male's first names and full names
    boy_fullnames = getFullNames(boy_links)
    boy_firstnames = getFirstNames(boy_fullnames, lname)
    # get female's first names and full names
    girl_fullnames = getFullNames(girl_links)
    girl_firstnames = getFirstNames(girl_fullnames, lname)
    
    # -------writing name info----------
    f = writer
    # writing male's name info
    for i in range(len(boy_fullnames)):
        f.write('\n')
        f.write(template.format(lname, boy_firstnames[i], boy_fullnames[i], 'M'))
    # writing female's name info
    for i in range(len(girl_fullnames)):
        f.write('\n')
        f.write(template.format(lname, girl_firstnames[i], girl_fullnames[i], 'F'))
    print(f'Finish writing name info related to {lname}...')

# %%
def main():
    url = 'http://www.resgain.net/xmdq.html'
    # Get the last names, counts of unique full names related with the last times, and the links
    lastNames, counts, links = getMetaData(url)
    # 中国人名信息库 = Chinese Name Info Corpus
    f = open('中国人名信息库.txt', 'w')
    template = '{}\t{}\t{}\t{}'
    f.write(template.format('姓', '名', '全名', '性别'))
    end_idx = len(lastNames)
    for i in range(0, end_idx, 10):
        # multithreading conducted batch by batch to avoid losing connections 
        threads = []
        for idx in range(i, i + 10 if i+10<=end_idx else end_idx):
            t = Thread(target=nameInfoWriter, args=(lastNames[idx], links[idx], f, template,))
            t.start()
            threads.append(t)
        for t in threads:
            t.join()
    f.close()
    
    # writing the metadata
    template = '{}\t{}\t{}'
    # 元数据 = metadata
    with open('元数据.txt', 'w') as f:
        f.write(template.format('姓', '姓名数', '链接'))
        for i in range(len(lastNames)):
            f.write('\n')
            f.write(template.format(lastNames[i], counts[i], links[i]))
        f.close()

# %%
<bound method Tag._all_strings of <a class="btn btn2" href="name_list.rhtml?fid=1" title="	赵姓名字大全共有赵姓名字162998个">赵姓名字大全</a>>

# %%
if __name__ == '__main__':
    s = time()
    main()
    e = time()
    print("Total time: " + str(e - s))
# Out:
# Exception in thread Thread-4 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
# Exception in thread Thread-5 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
# Exception in thread Thread-6 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
# Exception in thread Thread-7 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
# Exception in thread Thread-8 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
# Exception in thread Thread-9 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
# Exception in thread Thread-10 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
# Exception in thread Thread-11 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
# Exception in thread Thread-12 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
# Exception in thread Thread-13 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=2': No host supplied
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=3': No host supplied
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=6': No host supplied
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=7': No host supplied
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=4': No host supplied
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=5': No host supplied
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=1': No host supplied
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=9': No host supplied
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=10': No host supplied
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=8': No host supplied
# Exception in thread Thread-14 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
# Exception in thread Thread-15 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
# Exception in thread Thread-16 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
# Exception in thread Thread-17 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
# Exception in thread Thread-18 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
# Exception in thread Thread-19 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
# Exception in thread Thread-20 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
# Exception in thread Thread-21 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
# Exception in thread Thread-22 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
# Exception in thread Thread-23 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=11': No host supplied
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=18': No host supplied
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=13': No host supplied
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=14': No host supplied
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=12': No host supplied
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=15': No host supplied
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=20': No host supplied
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=16': No host supplied
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=17': No host supplied
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=19': No host supplied
# Exception in thread Thread-25 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
# Exception in thread Thread-24 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
# Exception in thread Thread-26 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
# Exception in thread Thread-27 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
# Exception in thread Thread-28 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
# Exception in thread Thread-29 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
# Exception in thread Thread-30 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
# Exception in thread Thread-31 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
# Exception in thread Thread-32 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
# Exception in thread Thread-33 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=22': No host supplied
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     return session.request(method=method, url=url, **kwargs)
# ...
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=645': No host supplied
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=647': No host supplied
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=643': No host supplied
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=646': No host supplied
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=649': No host supplied
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=648': No host supplied
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=652': No host supplied
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=651': No host supplied
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=650': No host supplied
# Exception in thread Thread-644 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
# Exception in thread Thread-646 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
# Exception in thread Thread-645 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
# Exception in thread Thread-647 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
# Exception in thread Thread-648 (nameInfoWriter):
# Traceback (most recent call last):
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     self.run()
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     _threading_Thread_run(self)
#   File "/home/bravo6k/miniconda3/lib/python3.12/threading.py", line 1010, in run
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_131686/3338145180.py", line 118, in nameInfoWriter
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#   File "/tmp/ipykernel_131686/3338145180.py", line 71, in getFullNames
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#   File "/tmp/ipykernel_131686/3338145180.py", line 8, in getHTML
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 73, in get
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     return request("get", url, params=params, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=655': No host supplied
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     return session.request(method=method, url=url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 575, in request
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     prep = self.prepare_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/sessions.py", line 484, in prepare_request
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     p.prepare(
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 367, in prepare
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     self.prepare_url(url, params)
#   File "/home/bravo6k/miniconda3/lib/python3.12/site-packages/requests/models.py", line 444, in prepare_url
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=657': No host supplied
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=656': No host supplied
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=654': No host supplied
#     raise InvalidURL(f"Invalid URL {url!r}: No host supplied")
# requests.exceptions.InvalidURL: Invalid URL 'http:name/boys_1.rhtml?fid=653': No host supplied
# Total time: 7.211263418197632

# %%
with open('Chinese_Names.txt', 'a') as f:
    f.write(open('../中国人名语料库.txt', 'r').read())
    f.close()
